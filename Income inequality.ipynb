# %%
import matplotlib. pyplot as plt
x =[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
y= [44.87,45.17,45.32, 45.2, 45.38,45.83, 45.92, 46.42, 46.36, 46.57]
plt.plot(x,y,label= ('MATERNAL DEATHS'))
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('INCOME INEQUALITY')
plt.legend()
